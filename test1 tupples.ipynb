# %%
import numpy as np
import matplotlib as mp
import uproot

# %%
data=uproot.open('/data_CMS/cms/sauvan/HGCAL/Ntuples/ForAlexandre/ntuple.root')

# %%
data.keys()
# Out:
# [b'Floatingpoint7SupertriggercellDummyHistothresholdMultiClustersNtuple;1',
#  b'Floatingpoint7ThresholdDummyHistothresholdMultiClustersNtuple;1',
#  b'Floatingpoint7BestchoiceDummyHistothresholdMultiClustersNtuple;1',
#  b'Floatingpoint7ThresholdDummyHistoMaxMultiClustersNtuple;1',
#  b'Floatingpoint7ThresholdDummyHistoMaxVarDRMultiClustersNtuple;1',
#  b'Floatingpoint7ThresholdDummyHistoInterpolatedMaxMultiClustersNtuple;1',
#  b'Floatingpoint7ThresholdDummyHistoInterpolatedMax1stOrderMultiClustersNtuple;1',
#  b'Floatingpoint7ThresholdDummyHistoInterpolatedMax2ndOrderMultiClustersNtuple;1']

# %%
tree=data['Floatingpoint7SupertriggercellDummyHistothresholdMultiClustersNtuple']

# %%
dataExample=data['Floatingpoint7SupertriggercellDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']

# %%
dataExample.show()
# Out:
# run                        (no streamer)              asdtype('>i4')
# event                      (no streamer)              asdtype('>i4')
# lumi                       (no streamer)              asdtype('>i4')
# gen_n                      (no streamer)              asdtype('>i4')
# gen_PUNumInt               (no streamer)              asdtype('>i4')
# gen_TrueNumInt             (no streamer)              asdtype('>f4')
# vtx_x                      (no streamer)              asdtype('>f4')
# vtx_y                      (no streamer)              asdtype('>f4')
# vtx_z                      (no streamer)              asdtype('>f4')
# gen_eta                    TStreamerSTL               asjagged(asdtype('>f4'), 10)
# gen_phi                    TStreamerSTL               asjagged(asdtype('>f4'), 10)
# gen_pt                     TStreamerSTL               asjagged(asdtype('>f4'), 10)
# gen_energy                 TStreamerSTL               asjagged(asdtype('>f4'), 10)
# ...

# %%
dataExample['cl3d_seetot'].array()
# Out:
# <JaggedArray [[] [] [] ... [0.026801301166415215 0.00617173919454217 0.014932965859770775 ... 0.006895115133374929 0.009803115390241146 0.02438144013285637] [0.025411415845155716 0.01936108060181141 0.021860364824533463 ... 0.008126660250127316 0.004928065463900566 0.004789996892213821] [0.10720474272966385 0.03822505846619606 0.0983443632721901 ... 0.011745569296181202 0.00975997094064951 0.029472222551703453]] at 0x7fe83148de48>

# %%
#print(tree['cl3d_n'].array(), tree['genpart_gen'].array())

# %%
#tree.pandas.df(['event','run','lumi','gen_n']).head(10)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.hist(data['Floatingpoint7SupertriggercellDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_n'].array(),histtype='step',label='SupertriggercellDummyHistothresholdMultiClusters')
plt.hist(data['Floatingpoint7ThresholdDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_n'].array(),histtype='step',label='ThresholdDummyHistothresholdMultiClusters')
plt.hist(data['Floatingpoint7BestchoiceDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_n'].array(),histtype='step',label='BestchoiceDummyHistothresholdMultiClusters')
plt.hist(data['Floatingpoint7ThresholdDummyHistoMaxMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_n'].array(),histtype='step',label='ThresholdDummyHistoMaxMultiClusters')
plt.hist(data['Floatingpoint7ThresholdDummyHistoMaxVarDRMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_n'].array(),histtype='step',label='ThresholdDummyHistoMaxVarDRMultiClusters')
plt.hist(data['Floatingpoint7ThresholdDummyHistoInterpolatedMaxMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_n'].array(),histtype='step',label='ThresholdDummyHistoInterpolatedMaxMultiClusters')
plt.hist(data['Floatingpoint7ThresholdDummyHistoInterpolatedMax1stOrderMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_n'].array(),histtype='step',label='ThresholdDummyHistoInterpolatedMax1stOrderMultiClusters')
plt.hist(data['Floatingpoint7ThresholdDummyHistoInterpolatedMax2ndOrderMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_n'].array(),histtype='step',label='ThresholdDummyHistoInterpolatedMax2ndOrderMultiClusters')
plt.xlabel('number of cluster',fontsize=12)
plt.ylabel('Events',fontsize=12)
plt.legend(frameon=False)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
nbin=20
plt.hist(data['Floatingpoint7SupertriggercellDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_showerlength'].array(flatten=True),histtype='step',bins=nbin,label='SupertriggercellDummyHistothresholdMultiClusters')
plt.hist(data['Floatingpoint7ThresholdDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_showerlength'].array(flatten=True),histtype='step',bins=nbin,label='ThresholdDummyHistothresholdMultiClusters')
plt.hist(data['Floatingpoint7BestchoiceDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_showerlength'].array(flatten=True),histtype='step',bins=nbin,label='BestchoiceDummyHistothresholdMultiClusters')
plt.hist(data['Floatingpoint7ThresholdDummyHistoMaxMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_showerlength'].array(flatten=True),histtype='step',bins=nbin,label='ThresholdDummyHistoMaxMultiClusters')
plt.hist(data['Floatingpoint7ThresholdDummyHistoMaxVarDRMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_showerlength'].array(flatten=True),histtype='step',bins=nbin,label='ThresholdDummyHistoMaxVarDRMultiClusters')
plt.hist(data['Floatingpoint7ThresholdDummyHistoInterpolatedMaxMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_showerlength'].array(flatten=True),histtype='step',bins=nbin,label='ThresholdDummyHistoInterpolatedMaxMultiClusters')
plt.hist(data['Floatingpoint7ThresholdDummyHistoInterpolatedMax1stOrderMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_showerlength'].array(flatten=True),histtype='step',bins=nbin,label='ThresholdDummyHistoInterpolatedMax1stOrderMultiClusters')
plt.hist(data['Floatingpoint7ThresholdDummyHistoInterpolatedMax2ndOrderMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_showerlength'].array(flatten=True),histtype='step',bins=nbin,label='ThresholdDummyHistoInterpolatedMax2ndOrderMultiClusters')
plt.xlabel('Shower length',fontsize=12)
plt.ylabel('Events',fontsize=12)
plt.legend(frameon=False)

# %%
# Out:
# <JaggedArray [[] [] [] ... [28 7 23 ... 28 15 29] [10 14 19 ... 24 10 15] [87 11 64 ... 32 20 29]] at 0x7fe82dd5d9e8>

# %%
test=dataExample['cl3d_energy'].array(flatten=True)
plt.figure(figsize=(10,10))
plt.hist(test,histtype='step',label='cl3d')
plt.hist(data['Floatingpoint7SupertriggercellDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['genpart_energy'].array(flatten=True), histtype='step', color='red', label='gen')
plt.xlabel('energy',fontsize=12)
plt.ylabel('Events',fontsize=12)
plt.legend(frameon=False)
plt.title('Distribution of energy of the SupertriggercellDummyHistothresholdMultiClusters method and true energy', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Distribution of energy of the SupertriggercellDummyHistothresholdMultiClusters method and true energy')

# %%
plt.figure(1,figsize=(15,25))
plt.subplot(421)
plt.hist(data['Floatingpoint7SupertriggercellDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_energy'].array(flatten=True),histtype='step',label='cl3d')
plt.hist(data['Floatingpoint7SupertriggercellDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['genpart_energy'].array(flatten=True), histtype='step', color='red', label='gen')
plt.xlabel('Energy',fontsize=10)
plt.ylabel('Events',fontsize=10)
plt.legend(frameon=False)
plt.title('SupertriggercellDummyHistothresholdMultiClusters', fontsize=12)

plt.subplot(422)
plt.hist(data['Floatingpoint7ThresholdDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_energy'].array(flatten=True),histtype='step',label='cl3d')
plt.hist(data['Floatingpoint7ThresholdDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['genpart_energy'].array(flatten=True), histtype='step', color='red', label='gen')
plt.xlabel('Energy',fontsize=10)
plt.ylabel('Events',fontsize=10)
plt.legend(frameon=False)
plt.title('ThresholdDummyHistothresholdMultiClusters', fontsize=12)

plt.subplot(423)
plt.hist(data['Floatingpoint7BestchoiceDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_energy'].array(flatten=True),histtype='step',label='cl3d')
plt.hist(data['Floatingpoint7BestchoiceDummyHistothresholdMultiClustersNtuple']['HGCalTriggerNtuple']['genpart_energy'].array(flatten=True), histtype='step', color='red', label='gen')
plt.xlabel('Energy',fontsize=10)
plt.ylabel('Events',fontsize=10)
plt.legend(frameon=False)
plt.title('BestchoiceDummyHistothresholdMultiClusters', fontsize=12)

plt.subplot(424)
plt.hist(data['Floatingpoint7ThresholdDummyHistoMaxMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_energy'].array(flatten=True),histtype='step',label='cl3d')
plt.hist(data['Floatingpoint7ThresholdDummyHistoMaxMultiClustersNtuple']['HGCalTriggerNtuple']['genpart_energy'].array(flatten=True), histtype='step', color='red', label='gen')
plt.xlabel('Energy',fontsize=10)
plt.ylabel('Events',fontsize=10)
plt.legend(frameon=False)
plt.title('ThresholdDummyHistoMaxMultiClusters', fontsize=12)

plt.subplot(425)
plt.hist(data['Floatingpoint7ThresholdDummyHistoMaxVarDRMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_energy'].array(flatten=True),histtype='step',label='cl3d')
plt.hist(data['Floatingpoint7ThresholdDummyHistoMaxVarDRMultiClustersNtuple']['HGCalTriggerNtuple']['genpart_energy'].array(flatten=True), histtype='step', color='red', label='gen')
plt.xlabel('Energy',fontsize=10)
plt.ylabel('Events',fontsize=10)
plt.legend(frameon=False)
plt.title('ThresholdDummyHistoMaxVarDRMultiClusters', fontsize=12)

plt.subplot(426)
plt.hist(data['Floatingpoint7ThresholdDummyHistoInterpolatedMaxMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_energy'].array(flatten=True),histtype='step',label='cl3d')
plt.hist(data['Floatingpoint7ThresholdDummyHistoInterpolatedMaxMultiClustersNtuple']['HGCalTriggerNtuple']['genpart_energy'].array(flatten=True), histtype='step', color='red', label='gen')
plt.xlabel('Energy',fontsize=10)
plt.ylabel('Events',fontsize=10)
plt.legend(frameon=False)
plt.title('ThresholdDummyHistoInterpolatedMaxMultiClusters', fontsize=12)

plt.subplot(427)
plt.hist(data['Floatingpoint7ThresholdDummyHistoInterpolatedMax1stOrderMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_energy'].array(flatten=True),histtype='step',label='cl3d')
plt.hist(data['Floatingpoint7ThresholdDummyHistoInterpolatedMax1stOrderMultiClustersNtuple']['HGCalTriggerNtuple']['genpart_energy'].array(flatten=True), histtype='step', color='red', label='gen')
plt.xlabel('Energy',fontsize=10)
plt.ylabel('Events',fontsize=10)
plt.legend(frameon=False)
plt.title('ThresholdDummyHistoInterpolatedMax1stOrderMultiClusters', fontsize=12)

plt.subplot(428)
plt.hist(data['Floatingpoint7ThresholdDummyHistoInterpolatedMax2ndOrderMultiClustersNtuple']['HGCalTriggerNtuple']['cl3d_energy'].array(flatten=True),histtype='step',label='cl3d')
plt.hist(data['Floatingpoint7ThresholdDummyHistoInterpolatedMax2ndOrderMultiClustersNtuple']['HGCalTriggerNtuple']['genpart_energy'].array(flatten=True), histtype='step', color='red', label='gen')
plt.xlabel('Energy',fontsize=10)
plt.ylabel('Events',fontsize=10)
plt.legend(frameon=False)
plt.title('ThresholdDummyHistoInterpolatedMax2ndOrderMultiClusters', fontsize=12)

plt.savefig('energy.png')
